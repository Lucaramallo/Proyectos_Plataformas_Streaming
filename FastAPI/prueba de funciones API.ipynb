# %% [markdown]
# # Funciones de la API:

# %%
import pandas as pd

# Cargar el archivo pickle en un DataFrame
df_merged = pd.read_pickle('../ETL/Data/merged.pickle')

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 305808 entries, 99612 to 31511
# Data columns (total 15 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   id                 305808 non-null  object
#  1   plataforma         305808 non-null  object
#  2   type               305808 non-null  object
#  3   title              305808 non-null  object
#  4   director           305808 non-null  object
#  5   cast               305808 non-null  object
#  6   country            305808 non-null  object
#  7   date_added         305808 non-null  object
#  8   release_year       305808 non-null  object
#  9   rating             305808 non-null  object
#  10  duration_int       305808 non-null  object
#  11  duration_type      305808 non-null  object
#  12  listed_in          305808 non-null  object
#  13  description        305808 non-null  object
#  14  rating_movie_user  305808 non-null  float64
# dtypes: float64(1), object(14)
# ...

# %%
df_merged = df_merged.astype({
    "id": "object",
    "plataforma": "object",
    "type": "category",
    "title": "object",
    "director": "object",
    "cast": "object",
    "country": "object",
    "date_added": "datetime64[ns]",
    "release_year": "int64",
    "rating": "category",
    "duration_int": "int64",
    "duration_type": "category",
    "listed_in": "object",
    "description": "object",
    "rating_movie_user": "float64"
})

# %%
df_merged.head(10)
# Out:
#            id plataforma     type                     title director
# 99612  as2451        aws  tv show  fluffy's food adventures  unknown  \
# 99616  as2451        aws  tv show  fluffy's food adventures  unknown
# 99628  as2451        aws  tv show  fluffy's food adventures  unknown
# 99627  as2451        aws  tv show  fluffy's food adventures  unknown
# 99626  as2451        aws  tv show  fluffy's food adventures  unknown
# 99625  as2451        aws  tv show  fluffy's food adventures  unknown
# 99624  as2451        aws  tv show  fluffy's food adventures  unknown
# 99623  as2451    netflix  tv show            midnight diner  unknown
# 99622  as2451        aws  tv show  fluffy's food adventures  unknown
# 99621  as2451    netflix  tv show            midnight diner  unknown
#
#                                                     cast  country date_added
# 99612    gabriel iglesias, rick gutierrez, martin moreno  unknown 2021-07-14  \
# ...

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 305808 entries, 99612 to 31511
# Data columns (total 15 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   id                 305808 non-null  object
#  1   plataforma         305808 non-null  object
#  2   type               305808 non-null  category
#  3   title              305808 non-null  object
#  4   director           305808 non-null  object
#  5   cast               305808 non-null  object
#  6   country            305808 non-null  object
#  7   date_added         305808 non-null  datetime64[ns]
#  8   release_year       305808 non-null  int64
#  9   rating             305808 non-null  category
#  10  duration_int       305808 non-null  int64
#  11  duration_type      305808 non-null  category
#  12  listed_in          305808 non-null  object
#  13  description        305808 non-null  object
#  14  rating_movie_user  305808 non-null  float64
# ...

# %%
df_merged.describe()
# Out:
#                           date_added   release_year   duration_int
# count                         305808  305808.000000  305808.000000  \
# mean   2020-09-08 18:03:57.325380608    2009.911435      70.826303
# min              2008-01-01 00:00:00    1920.000000       0.000000
# 25%              2019-12-03 00:00:00    2009.000000       9.000000
# 50%              2021-07-14 00:00:00    2016.000000      86.000000
# 75%              2021-07-14 00:00:00    2019.000000     102.000000
# max              2021-11-26 00:00:00    2021.000000     601.000000
# std                              NaN      16.823827      50.671895
#
#        rating_movie_user
# count      305808.000000
# mean            0.443794
# min             0.000000
# 25%             0.354530
# 50%             0.440464
# 75%             0.529322
# max             0.970207
# std             0.129992

# %% [markdown]
# # Listado de Funciones:

# %% [markdown]
# ### Funcion 1:
#
# #### Película (sólo película, no serie, etc) con mayor duración según año, plataforma y tipo de duración. La función debe llamarse get_max_duration(year, platform, duration_type) y debe devolver sólo el string del nombre de la película.

# %%
import pandas as pd


def get_max_duration(year, platform, duration_type):

    
    # Filtrar el DataFrame para incluir solo las películas
    movies_df = df_merged[df_merged['type'] == 'movie']
    
    # Convertir la columna 'duration_int' a valores numéricos
    movies_df['duration_int'] = pd.to_numeric(movies_df['duration_int'], errors='coerce')
    
    # Filtrar por año, plataforma y tipo de duración
    filtered_df = movies_df[(movies_df['release_year'] == year) & 
                            (movies_df['plataforma'] == platform) &
                            (movies_df['duration_type'] == duration_type)]
    
    # Devolver el título de la película con la duración máxima
    max_duration_movie = filtered_df.loc[filtered_df['duration_int'].idxmax(), 'title']
    
    # Crear el diccionario de salida
    output_dict = {
        'plataforma': platform,
        'tipo_duracion': duration_type,
        'año': year,
        'titulo': max_duration_movie
    }
    
    return output_dict

# %%
get_max_duration(2000, 'netflix', 'min')
# Out:
# C:\Users\Luca\AppData\Local\Temp\ipykernel_4544\27765233.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies_df['duration_int'] = pd.to_numeric(movies_df['duration_int'], errors='coerce')
# {'plataforma': 'netflix',
#  'tipo_duracion': 'min',
#  'año': 2000,
#  'titulo': 'pukar'}

# %% [markdown]
# ### Funcion 2:
# #### Cantidad de películas (sólo películas, no series, etc) según plataforma, con un puntaje mayor a XX en determinado año. La función debe llamarse get_score_count(platform, scored, year) y debe devolver un int, con el total de películas que cumplen lo solicitado.

# %%
def get_score_count(plataforma: str, scored: float, anio: int):
    # Filtrar sólo las películas del año y plataforma solicitados
    movies = df_merged[(df_merged['plataforma'] == plataforma) & 
                       (df_merged['type'] == 'movie') &
                       (df_merged['release_year'] == anio)]
    
    # Contar las películas que cumplen con el puntaje mínimo
    count = (movies['rating_movie_user'] >= scored).sum()
    
    return {
        'plataforma': plataforma,
        'cantidad': count,
        'anio': anio,
        'score': scored
    }


# Get the number of movies on Netflix with a score of 4.0 or higher released in 2021
count = get_score_count('netflix',3.5, 2021)
print(count)  # prints e.g. 25
# Out:
# {'plataforma': 'netflix', 'cantidad': 0, 'anio': 2021, 'score': 3.5}

# %% [markdown]
# # segun tengo entendido para este caso sera necesario convertir la columna rating a valores solo numericos

# %% [markdown]
# ### Funcion 3:
# #### Cantidad de películas (sólo películas, no series, etc) según plataforma. La función debe llamarse get_count_platform(platform) y debe devolver un int, con el número total de películas de esa plataforma. Las plataformas deben llamarse amazon, netflix, hulu, disney.

# %%
def get_count_platform(plataforma: str):
    platform_df = df_merged[df_merged['type'] == 'movie']
    respuesta = len(platform_df[platform_df['plataforma'] == plataforma])
    return {'plataforma': plataforma, 'peliculas': respuesta}

# %%
get_count_platform('netflix')
# Out:
# {'plataforma': 'netflix', 'peliculas': 73572}

# %% [markdown]
# ### Funcion 4:
# #### Actor que más se repite según plataforma y año. La función debe llamarse get_actor(platform, year) y debe devolver sólo el string con el nombre del actor que más se repite según la plataforma y el año dado.

# %%
def get_actor(plataforma: str, anio: int):
    # get data for the given platform and year
    platform_data = df_merged[df_merged['plataforma'] == plataforma]
    year_data = platform_data[platform_data['release_year'] == anio]

    # concatenate the cast and director fields
    year_data['combined'] = year_data['cast'] + ',' + year_data['director']

    # get the actor or director that appears most frequently
    combined_counts = year_data['combined'].value_counts()
    max_count = combined_counts.max()
    top_actors = combined_counts[combined_counts == max_count]
    most_frequent_actor = top_actors.index[0]

    # separate the actor and director names
    most_frequent_actor_parts = most_frequent_actor.split(',')
    most_frequent_cast = most_frequent_actor_parts[0]
    most_frequent_director = most_frequent_actor_parts[1]

    # create the output dictionary
    return{
        'plataforma': plataforma,
        'anio': anio,
        'actor': most_frequent_cast,
        'apariciones': max_count}

# %%
get_actor('netflix', 1999)
# Out:
# C:\Users\Luca\AppData\Local\Temp\ipykernel_4544\1449474326.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   year_data['combined'] = year_data['cast'] + ',' + year_data['director']
# {'plataforma': 'netflix',
#  'anio': 1999,
#  'actor': 'tony goldwyn',
#  'apariciones': 12}

# %% [markdown]
# ### Funcion 5:
# #### La cantidad de contenidos/productos (todo lo disponible en streaming) que se publicó por país y año. La función debe llamarse prod_per_county(tipo,pais,anio) deberia devolver el tipo de contenido (pelicula,serie) por pais y año en un diccionario con las variables llamadas 'pais' (nombre del pais), 'anio' (año), 'pelicula' (tipo de contenido).

# %%
def prod_per_county(tipo: str, pais: str, anio: int):
    # filtrar los datos según el tipo de contenido, país y año
    df_filt = df_merged[(df_merged['type'] == tipo) & (df_merged['country'] == pais) & (df_merged['release_year'] == anio)]
    # contar el número de filas
    respuesta = len(df_filt)
    # crear un diccionario con los resultados y devolverlo
    result = {'pais': pais, 'anio': anio, 'peliculas': tipo, 'count': respuesta}
    return {'pais': pais, 'anio': anio, 'peliculas': respuesta}

prod_per_county('movie', 'united states',2000)
# Out:
# {'pais': 'united states', 'anio': 2000, 'peliculas': 390}

# %% [markdown]
# ### Funcion 6:
# #### La cantidad total de contenidos/productos (todo lo disponible en streaming, series, peliculas, etc) según el rating de audiencia dado (para que publico fue clasificada la pelicula). La función debe llamarse get_contents(rating) y debe devolver el numero total de contenido con ese rating de audiencias.

# %%
def get_contents(rating: str):
    # Filtrar el DataFrame por el rating de audiencia dado
    contents = df_merged[df_merged['rating'] == rating]
    # Obtener el número total de contenidos
    num_contents = contents.shape[0]
    # Devolver una respuesta en formato JSON
    respuesta = {'rating': rating, 'num_contents': num_contents}
    return {'rating': rating, 'contenido': num_contents}

get_contents('tv-14')
# Out:
# {'rating': 'tv-14', 'contenido': 31086}

# %% [markdown]
# ### Funcion 7 - Modelo Recomendador:
# #### Para desarrollar luego.... Continuará...

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd

# Leer el archivo pickle y guardar los datos en un DataFrame
merged_df = pd.read_pickle('../ETL/Data/merged.pickle')

def get_recommendation(titulo):
    # Obtener la película dada por su título
    pelicula = merged_df[merged_df['title'] == titulo].iloc[0]
    
    # Crear una lista con los títulos de todas las películas
    titulos = merged_df['title'].tolist()
    
    # Crear una matriz de recuento de términos de la columna "listed_in"
    vectorizer = CountVectorizer()
    generos_matriz = vectorizer.fit_transform(merged_df.iloc[:, 7:])
    
    # Obtener el índice de la película dada
    idx = titulos.index(titulo)
    
    # Obtener los vectores de características de todas las películas
    pelicula_features = generos_matriz[idx]
    features_matriz = generos_matriz
    
    # Calcular la similitud del coseno entre la película dada y todas las demás películas
    similarities = cosine_similarity(pelicula_features, features_matriz).flatten()
    
    # Obtener los índices de las películas más similares
    similar_indices = similarities.argsort()[-2:-1][::-1]
    
    # Obtener los títulos de las películas más similares
    similar_titulos = [titulos[i] for i in similar_indices]
    
    return similar_titulos
get_recommendation("lionheart")# pr ahora este
# Out:
# ['we bought a zoo']

# %% [markdown]
# _________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# # EDA:

# %% [markdown]
# Análisis exploratorio de los datos: (Exploratory Data Analysis-EDA)
#
# Ya los datos están limpios, ahora es tiempo de investigar las relaciones que hay entre las variables de los datasets, ver si hay outliers o anomalías (que no tienen que ser errores necesariamente 👀 ), y ver si hay algún patrón interesante que valga la pena explorar en un análisis posterior. Sabes que puedes apoyarte en librerías como pandas profiling, sweetviz, autoviz, entre otros y sacar de allí tus conclusiones 😉

# %% [markdown]
# # Sistema de recomendación:
#
# Una vez que toda la data es consumible por la API, está lista para consumir por los departamentos de Analytics y Machine Learning, y nuestro EDA nos permite entender bien los datos a los que tenemos acceso, es hora de entrenar nuestro modelo de machine learning para armar un sistema de recomendación de películas. Éste consiste en recomendar películas a los usuarios basándose en películas similares, por lo que se debe encontrar la similitud de puntuación entre esa película y el resto de películas, se ordenarán según el score y devolverá una lista de Python con 5 valores, cada uno siendo el string del nombre de las películas con mayor puntaje, en orden descendente. Debe ser deployado como una función adicional de la API anterior y debe llamarse get_recommendation(titulo: str).

# %% [markdown]
# # ME GUSTARIA CREAR UNO DESDE EL LADO MOVIES RATINGS; Y OTR DESDE LA PERSPECTIVA DEL USUARIO,, COMBINAR AMBOS EXTREMOS

# %%
import matplotlib.pyplot as plt
df_merged.tail()
# Out:
#           id   plataforma   type            title        director
# 31501  as657  disney plus  movie    cool runnings  jon turteltaub  \
# 31500  as657          aws  movie         the flaw   david sington
# 31499  as657      netflix  movie  love is a story  cristina jacob
# 31498  as657  disney plus  movie    cool runnings  jon turteltaub
# 31511  as657      netflix  movie  love is a story  cristina jacob
#
#                                                     cast         country
# 31501  leon , doug doug, rawle lewis, malik yoba, ray...   united states  \
# 31500           andrew luan, robert shiller, louis hyman  united kingdom
# 31499            raluca aprodu, dragoș bucur, ducu darie         romania
# 31498  leon , doug doug, rawle lewis, malik yoba, ray...   united states
# 31511            raluca aprodu, dragoș bucur, ducu darie         romania
#
#       date_added  release_year rating  duration_int duration_type
# ...

# %% [markdown]
# TRABAJAREUN SISTEMA QUE ANALICE A LOS USUARIOS DE MANERA DE PODER COMBINAR
# .... TO BE CONTINUED

# %% [markdown]
# _____________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# # Algunos EDA:...

# %%
plt.hist(df_merged['rating'], bins=10)
plt.xlabel('Rating')
plt.ylabel('Frecuencia')
plt.xticks(rotation=90)
plt.show()

# %%
import seaborn as sns

sns.countplot(data=df_merged, x="plataforma")
# Out:
# <Axes: xlabel='plataforma', ylabel='count'>

# %%
df_selected = df_merged[['release_year', 'duration_int', 'rating_user_movie']]
df_selected
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\Luca\Desktop\VsCode\Data Scientist\CURSADO HENRY DTS09\PI\PI 1\PI_ML_OPS-main\FastAPI\prueba de funciones API.ipynb Cell 40 in 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Luca/Desktop/VsCode/Data%20Scientist/CURSADO%20HENRY%20DTS09/PI/PI%201/PI_ML_OPS-main/FastAPI/prueba%20de%20funciones%20API.ipynb#X53sZmlsZQ%3D%3D?line=0'>1</a> df_selected = df_merged[['release_year', 'duration_int', 'rating_user_movie']]
#       <a href='vscode-notebook-cell:/c%3A/Users/Luca/Desktop/VsCode/Data%20Scientist/CURSADO%20HENRY%20DTS09/PI/PI%201/PI_ML_OPS-main/FastAPI/prueba%20de%20funciones%20API.ipynb#X53sZmlsZQ%3D%3D?line=1'>2</a> df_selected
#
# ...

# %%
df_merged['release_year'] = pd.to_numeric(df_merged['release_year'], errors='coerce')
df_merged['duration_int'] = pd.to_numeric(df_merged['duration_int'], errors='coerce')
df_merged['mean_rating'] = pd.to_numeric(df_merged['mean_rating'], errors='coerce')
df_merged['vote_count'] = pd.to_numeric(df_merged['vote_count'], errors='coerce')
df_merged['growth_rate'] = pd.to_numeric(df_merged['growth_rate'], errors='coerce')

sns.pairplot(df_merged, vars=['release_year', 'duration_int', 'mean_rating', 'vote_count', 'growth_rate',])
